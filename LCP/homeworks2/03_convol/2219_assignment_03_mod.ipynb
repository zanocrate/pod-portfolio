# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

#import keras
#import tensorflow as tf
from keras import regularizers, initializers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D,Conv2D, MaxPooling1D,MaxPooling2D,MaxPooling3D, AveragePooling1D
from scipy.signal import detrend
import tensorflow.random as tf_r
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.models import clone_model

# random seed for reproducibility
np.random.seed(12345)
tf_r.set_seed(12345) 
plt.style.use('seaborn')

# %% [markdown]
# # Data Generation
#
# We will generate `N` samples composed by 2 time series of lenght `L`, populate each of these time series with a Brownian walk, and then add a `bump` pattern consisting of half the period of a sine wave, with amplitude and sign depending on the sample label.

# %%
# we want to add this pattern at various points of the gaussian time series and see if the CNN finds it

def pattern(i,z,a):
    # Z is the lenght of the "bump" due to half sin oscillation
    # a is the amplitude
    return int(a*np.sin((np.pi*i)/z))

# %%
N = 1000 # number of samples, prima era 100000
L = 200 # time-points in each samples
D = 2 # number of time series

DX = 50 # std of gaussian noise
bias = 5 # bias of gaussian noise

# pattern properties
signal_to_noise = 10
Z = 12
A = signal_to_noise*DX # default is 10*DX

n_class=3


x = np.zeros((N,L,D)) # empty array with N rows of (L,D) cells (samples)
y_l = np.random.randint(-1,2,N) # array of N random numbers between 0 and 2 representing the label
                                # 0 : no pattern
                                # -1 : first negative pattern and then positive one
                                # 1 : first positive pattern and then negative one

for i in range(x.shape[0]): # running through every sample
    
    # generate noisy time series
    for j in range(x.shape[1]): # running through every time point
        if j == 0:
            x[i][j] = np.random.normal(loc=bias,scale=DX,size=(1,D)).astype(int) # starting gaussian noise

        else:
            x[i][j] = x[i][j-1] + np.random.normal(loc=bias,scale=DX,size=(1,D)).astype(int) # adding gaussian noise

    # generate pattern
    # we will generate them with a little temporal offset of 3 time points
    offset = 10
    j0 = np.random.randint(0,x.shape[1]-(Z+offset)) # do not pick the random pattern starting point closer to the edge than a whole pattern
    sign = np.sign(y_l[i])

    for j in range(0,Z):
        x[i][j0+j][0] += sign*pattern(j,Z,A)
        x[i][j0+j+offset][1] += -sign*pattern(j/2,Z,A) # second pattern a bit shifted and with a different shape,opposite sign

# %%
# now to reorganize the label: instead of having an array of N numbers being either 0 or 1 or 2 corresponding to the three classes
# we will have a (N,3) array with each of the N entry being a zero vector with a 1 where the corresponding class is.
y = np.zeros((N,3))

for i in range(N):
    y[i][y_l[i] + 1] = 1

# %%
#counting how many elements for each class
print("N# of elements in each class")
print(np.count_nonzero(y,axis=0))
# mask for elements of each class
first_class=np.argwhere(y[:,0]==1).reshape(-1)
second_class=np.argwhere(y[:,1]==1).reshape(-1)
third_class=np.argwhere(y[:,2]==1).reshape(-1)
# Out:
# N# of elements in each class
# [325 352 323]

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (16,5), sharey = True)
colors=['red','blue']
i=np.random.randint(30)
i_plts = [first_class[i],second_class[i],third_class[i]]
print(i_plts)
for ax, i_plt in zip(axs,i_plts):
    for d in range(D):
         ax.plot(x[i_plt,:,d],color=colors[d])
    ax.set_title("DATA n# {}, label y={}".format(i_plt,y[i_plt]))

plt.show()
# Out:
# [105, 84, 76]

# %%
# save data
! mkdir -p DATA2_03
str0 = f'ts_L{L}_Z{Z}_A{A}_DX{DX}_bias{bias}_N{N}.dat'
fname='DATA2_03/x_'+str0
# we need to save them as .npy files as tabular data generated by savetxt cannot store 3D or higher dimensional arrays
np.save(fname,x)
fname='DATA/y_'+str0
np.save(fname,y)

# %% [markdown]
# # Data preparation
#
# Now for data preparation: we will not reload the files as they have been generated in this very notebook.
#
# First thing we will try to *detrend* the data: that is, assume a linear background trend, we will interpolate this drift and subtract it from the original time series. To do that, we will implement the convenient `scipy.detrend` 's routine. Then we will rescale data by its variance.

# %%
# DETRENDING AND RESCALING

for i in range(x.shape[0]):
    for d in range(x.shape[2]):
        x[i,:,d] = detrend(x[i,:,d])
        
x = x/np.var(x)

# %%
#plotting 1 rescaled-detrended sample for each class

colors = ['red', 'blue']

fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (16,5), sharey = True)
for ax, i_plt in zip(axs,i_plts):
    for d in range(D):
         ax.plot(x[i_plt,:,d],color=colors[d])
    ax.set_title("DETRENDED RESCALED DATA n# {}, label y={}".format(i_plt,y[i_plt]))

plt.show()

# %% [markdown]
# ## Train-Test Split

# %%
perc_training = 0.8
n_train = int(x.shape[0]*0.8)

x_train,y_train = x[:n_train],y[:n_train]
x_val,y_val = x[n_train:],y[n_train:]


# Keras wants an additional dimension ???
# because Conv2D input is (samples,height,width,channels)


x_train = x_train.reshape(x_train.shape[0], L,D,1)
x_val =  x_val.reshape(x_val.shape[0], L,D,1)

print(x.shape)
print(x_train.shape)
# Out:
# (1000, 200, 2)
# (800, 200, 2, 1)

# %% [markdown]
# # Build model

# %%
#ridge regularization
reg = regularizers.l2(0.0002) # l2 is ridge, l1 would be lasso

# initializing weights
ini = initializers.RandomNormal(mean=1.0, stddev=0.05, seed=12345)

M = 15 # lenght of kernel: its shape will be (M,2)

# %%
# defining the model

model = Sequential()

model.add(Conv2D(filters=2, kernel_size = (M,2), kernel_initializer=ini, kernel_regularizer=reg,\
                 input_shape=x_train[0].shape, use_bias=False))

# lets try to build a pooling such that we detect the maximum correlation at some point in time
# this pools 2 neighbouring points along time axis
# so that output is half the width. hopefully this will catch the offset

model.add(MaxPooling2D(pool_size=(2,1)))

model.add(Conv2D(filters=2, kernel_size = (int(M/2),1)))

model.add(Flatten())
model.add(Dense(12,activation='sigmoid')) # 12 neurons layer
model.add(Dense(n_class,activation='softmax'))

print('----- MODEL SUMMARY ------')
print(model.summary())


opt = Adam()

# compile the model
model.compile(loss=categorical_crossentropy,optimizer=opt,metrics=['accuracy'])
# Out:
# ----- MODEL SUMMARY ------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 186, 1, 2)         60
#
#  max_pooling2d (MaxPooling2D  (None, 93, 1, 2)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 1, 2)          30
#
#  flatten (Flatten)           (None, 174)               0
#
#  dense (Dense)               (None, 12)                2100
#
#  dense_1 (Dense)             (None, 3)                 39
#
# =================================================================
# Total params: 2,229
# Trainable params: 2,229
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv2D at 0x7fb5fd210c40>,
#  <keras.layers.pooling.MaxPooling2D at 0x7fb600fcd0d0>,
#  <keras.layers.convolutional.Conv2D at 0x7fb600fcd2e0>,
#  <keras.layers.core.flatten.Flatten at 0x7fb600fcd040>,
#  <keras.layers.core.dense.Dense at 0x7fb5fd2c35e0>,
#  <keras.layers.core.dense.Dense at 0x7fb5fd2c3430>]

# %%
w = model.layers[0].get_weights()[0]
print(w.shape) #2 filters, for 1 channel, of a 15x2 kernel
# print(b.shape) # 3 bias for each filter
# Out:
# (15, 2, 1, 2)

# %%
#plotting weights of the first convolutional layer befor training

fig,axs = plt.subplots(2,1,figsize=[12,6])
fig.suptitle('Model Layer #1 Before training')
for i in range(w.shape[-1]): # for every filter
    axs[0].plot(w[:,0,0,i],marker='d',label=f'Filter n#{i}')
axs[0].legend()
axs[0].set_title('Weights, Time Series #1')
axs[0].set_xlabel('Window Index')

for i in range(w.shape[-1]): # for every filter
    axs[1].plot(w[:,1,0,i],marker='d',label=f'Filter n#{i}') #cambiato: prima era w[:,0,0,i]
axs[1].legend()
axs[1].set_title('Weights, Time Series #2')
axs[1].set_xlabel('Window Index')


fig.tight_layout()

# %% [markdown]
# # Training

# %%
batch_size = 500 #prima era 1000
epochs = 250

print('------- Model  ------- \n FITTING....')
fit = model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_val,y_val),verbose=1,shuffle=True)
# Out:
# ------- Model  -------
#  FITTING....
# Epoch 1/250
# 2/2 [==============================] - 0s 38ms/step - loss: 1.0734 - accuracy: 0.4512 - val_loss: 1.1177 - val_accuracy: 0.3650
# Epoch 2/250
# 2/2 [==============================] - 0s 50ms/step - loss: 1.0734 - accuracy: 0.4512 - val_loss: 1.1177 - val_accuracy: 0.3650
# Epoch 3/250
# 2/2 [==============================] - 0s 37ms/step - loss: 1.0733 - accuracy: 0.4525 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 4/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0733 - accuracy: 0.4538 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 5/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0732 - accuracy: 0.4550 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 6/250
# 2/2 [==============================] - 0s 48ms/step - loss: 1.0731 - accuracy: 0.4538 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 7/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0731 - accuracy: 0.4512 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 8/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0730 - accuracy: 0.4512 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 9/250
# 2/2 [==============================] - 0s 52ms/step - loss: 1.0730 - accuracy: 0.4512 - val_loss: 1.1176 - val_accuracy: 0.3700
# Epoch 10/250
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0729 - accuracy: 0.4525 - val_loss: 1.1176 - val_accuracy: 0.3750
# Epoch 11/250
# 2/2 [==============================] - 0s 81ms/step - loss: 1.0729 - accuracy: 0.4525 - val_loss: 1.1175 - val_accuracy: 0.3750
# Epoch 12/250
# 2/2 [==============================] - 0s 48ms/step - loss: 1.0728 - accuracy: 0.4525 - val_loss: 1.1175 - val_accuracy: 0.3750
# Epoch 13/250
# 2/2 [==============================] - 0s 39ms/step - loss: 1.0727 - accuracy: 0.4525 - val_loss: 1.1175 - val_accuracy: 0.3750
# Epoch 14/250
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0727 - accuracy: 0.4500 - val_loss: 1.1175 - val_accuracy: 0.3800
# Epoch 15/250
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0726 - accuracy: 0.4525 - val_loss: 1.1174 - val_accuracy: 0.3800
# Epoch 16/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0653 - accuracy: 0.4550 - val_loss: 1.1196 - val_accuracy: 0.3650
# Epoch 132/250
# 2/2 [==============================] - 0s 55ms/step - loss: 1.0652 - accuracy: 0.4563 - val_loss: 1.1196 - val_accuracy: 0.3700
# Epoch 133/250
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0652 - accuracy: 0.4550 - val_loss: 1.1196 - val_accuracy: 0.3700
# Epoch 134/250
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0651 - accuracy: 0.4550 - val_loss: 1.1195 - val_accuracy: 0.3700
# Epoch 135/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0650 - accuracy: 0.4550 - val_loss: 1.1195 - val_accuracy: 0.3700
# Epoch 136/250
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0650 - accuracy: 0.4550 - val_loss: 1.1195 - val_accuracy: 0.3700
# Epoch 137/250
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0649 - accuracy: 0.4550 - val_loss: 1.1195 - val_accuracy: 0.3700
# Epoch 138/250
# 2/2 [==============================] - 0s 79ms/step - loss: 1.0648 - accuracy: 0.4550 - val_loss: 1.1196 - val_accuracy: 0.3700
# Epoch 139/250
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0648 - accuracy: 0.4538 - val_loss: 1.1196 - val_accuracy: 0.3700
# Epoch 140/250
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0647 - accuracy: 0.4550 - val_loss: 1.1197 - val_accuracy: 0.3700
# Epoch 141/250
# 2/2 [==============================] - 0s 55ms/step - loss: 1.0646 - accuracy: 0.4550 - val_loss: 1.1197 - val_accuracy: 0.3650
# Epoch 142/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0645 - accuracy: 0.4550 - val_loss: 1.1198 - val_accuracy: 0.3650
# Epoch 143/250
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0645 - accuracy: 0.4563 - val_loss: 1.1198 - val_accuracy: 0.3650
# Epoch 144/250
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0644 - accuracy: 0.4563 - val_loss: 1.1199 - val_accuracy: 0.3650
# Epoch 145/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0643 - accuracy: 0.4538 - val_loss: 1.1199 - val_accuracy: 0.3650
# Epoch 146/250
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0642 - accuracy: 0.4538 - val_loss: 1.1200 - val_accuracy: 0.3650
# Epoch 147/250
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0642 - accuracy: 0.4550 - val_loss: 1.1201 - val_accuracy: 0.3650
# Epoch 148/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0642 - accuracy: 0.4563 - val_loss: 1.1201 - val_accuracy: 0.3700
# Epoch 149/250
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0641 - accuracy: 0.4563 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 150/250
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0640 - accuracy: 0.4613 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 151/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0639 - accuracy: 0.4613 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 152/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0638 - accuracy: 0.4613 - val_loss: 1.1202 - val_accuracy: 0.3650
# Epoch 153/250
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0638 - accuracy: 0.4613 - val_loss: 1.1203 - val_accuracy: 0.3600
# Epoch 154/250
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0637 - accuracy: 0.4613 - val_loss: 1.1203 - val_accuracy: 0.3600
# Epoch 155/250
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0637 - accuracy: 0.4613 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 156/250
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0636 - accuracy: 0.4588 - val_loss: 1.1202 - val_accuracy: 0.3650
# Epoch 157/250
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0635 - accuracy: 0.4638 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 158/250
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0634 - accuracy: 0.4625 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 159/250
# 2/2 [==============================] - 0s 53ms/step - loss: 1.0634 - accuracy: 0.4625 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 160/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0633 - accuracy: 0.4613 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 161/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0632 - accuracy: 0.4625 - val_loss: 1.1202 - val_accuracy: 0.3700
# Epoch 162/250
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0632 - accuracy: 0.4625 - val_loss: 1.1203 - val_accuracy: 0.3700
# Epoch 163/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0631 - accuracy: 0.4638 - val_loss: 1.1204 - val_accuracy: 0.3700
# Epoch 164/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0630 - accuracy: 0.4638 - val_loss: 1.1205 - val_accuracy: 0.3700
# Epoch 165/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0630 - accuracy: 0.4638 - val_loss: 1.1206 - val_accuracy: 0.3700
# Epoch 166/250
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0629 - accuracy: 0.4638 - val_loss: 1.1207 - val_accuracy: 0.3700
# Epoch 167/250
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0628 - accuracy: 0.4638 - val_loss: 1.1207 - val_accuracy: 0.3700
# Epoch 168/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0627 - accuracy: 0.4663 - val_loss: 1.1208 - val_accuracy: 0.3700
# Epoch 169/250
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0627 - accuracy: 0.4663 - val_loss: 1.1208 - val_accuracy: 0.3700
# Epoch 170/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0626 - accuracy: 0.4688 - val_loss: 1.1208 - val_accuracy: 0.3700
# Epoch 171/250
# 2/2 [==============================] - 0s 42ms/step - loss: 1.0625 - accuracy: 0.4725 - val_loss: 1.1208 - val_accuracy: 0.3700
# Epoch 172/250
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0624 - accuracy: 0.4737 - val_loss: 1.1209 - val_accuracy: 0.3700
# Epoch 173/250
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0624 - accuracy: 0.4750 - val_loss: 1.1209 - val_accuracy: 0.3700
# Epoch 174/250
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0623 - accuracy: 0.4750 - val_loss: 1.1209 - val_accuracy: 0.3650
# Epoch 175/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0622 - accuracy: 0.4750 - val_loss: 1.1209 - val_accuracy: 0.3700
# Epoch 176/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0621 - accuracy: 0.4762 - val_loss: 1.1208 - val_accuracy: 0.3700
# Epoch 177/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0621 - accuracy: 0.4750 - val_loss: 1.1208 - val_accuracy: 0.3750
# Epoch 178/250
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0620 - accuracy: 0.4737 - val_loss: 1.1208 - val_accuracy: 0.3750
# Epoch 179/250
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0619 - accuracy: 0.4725 - val_loss: 1.1208 - val_accuracy: 0.3700
# Epoch 180/250
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0618 - accuracy: 0.4750 - val_loss: 1.1208 - val_accuracy: 0.3600
# Epoch 181/250
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0618 - accuracy: 0.4712 - val_loss: 1.1209 - val_accuracy: 0.3550
# Epoch 182/250
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0617 - accuracy: 0.4712 - val_loss: 1.1209 - val_accuracy: 0.3550
# Epoch 183/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0616 - accuracy: 0.4712 - val_loss: 1.1210 - val_accuracy: 0.3550
# Epoch 184/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0615 - accuracy: 0.4712 - val_loss: 1.1211 - val_accuracy: 0.3550
# Epoch 185/250
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0614 - accuracy: 0.4712 - val_loss: 1.1212 - val_accuracy: 0.3650
# Epoch 186/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0614 - accuracy: 0.4688 - val_loss: 1.1213 - val_accuracy: 0.3650
# Epoch 187/250
# 2/2 [==============================] - 0s 99ms/step - loss: 1.0613 - accuracy: 0.4712 - val_loss: 1.1213 - val_accuracy: 0.3650
# Epoch 188/250
# 2/2 [==============================] - 0s 47ms/step - loss: 1.0613 - accuracy: 0.4712 - val_loss: 1.1213 - val_accuracy: 0.3700
# Epoch 189/250
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0612 - accuracy: 0.4712 - val_loss: 1.1213 - val_accuracy: 0.3700
# Epoch 190/250
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0611 - accuracy: 0.4712 - val_loss: 1.1213 - val_accuracy: 0.3650
# Epoch 191/250
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0610 - accuracy: 0.4700 - val_loss: 1.1213 - val_accuracy: 0.3650
# Epoch 192/250
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0609 - accuracy: 0.4712 - val_loss: 1.1213 - val_accuracy: 0.3650
# Epoch 193/250
# 2/2 [==============================] - 0s 83ms/step - loss: 1.0609 - accuracy: 0.4712 - val_loss: 1.1214 - val_accuracy: 0.3650
# Epoch 194/250
# 2/2 [==============================] - 0s 78ms/step - loss: 1.0608 - accuracy: 0.4712 - val_loss: 1.1214 - val_accuracy: 0.3600
# Epoch 195/250
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0607 - accuracy: 0.4712 - val_loss: 1.1213 - val_accuracy: 0.3600
# Epoch 196/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0606 - accuracy: 0.4725 - val_loss: 1.1213 - val_accuracy: 0.3600
# Epoch 197/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0606 - accuracy: 0.4725 - val_loss: 1.1213 - val_accuracy: 0.3600
# Epoch 198/250
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0605 - accuracy: 0.4737 - val_loss: 1.1214 - val_accuracy: 0.3600
# Epoch 199/250
# 2/2 [==============================] - 0s 49ms/step - loss: 1.0604 - accuracy: 0.4750 - val_loss: 1.1215 - val_accuracy: 0.3600
# Epoch 200/250
# 2/2 [==============================] - 0s 51ms/step - loss: 1.0603 - accuracy: 0.4750 - val_loss: 1.1215 - val_accuracy: 0.3600
# Epoch 201/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0602 - accuracy: 0.4750 - val_loss: 1.1215 - val_accuracy: 0.3600
# Epoch 202/250
# 2/2 [==============================] - 0s 55ms/step - loss: 1.0602 - accuracy: 0.4750 - val_loss: 1.1214 - val_accuracy: 0.3600
# Epoch 203/250
# 2/2 [==============================] - 0s 42ms/step - loss: 1.0601 - accuracy: 0.4762 - val_loss: 1.1214 - val_accuracy: 0.3600
# Epoch 204/250
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0600 - accuracy: 0.4800 - val_loss: 1.1213 - val_accuracy: 0.3600
# Epoch 205/250
# 2/2 [==============================] - 0s 47ms/step - loss: 1.0599 - accuracy: 0.4775 - val_loss: 1.1213 - val_accuracy: 0.3600
# Epoch 206/250
# 2/2 [==============================] - 0s 50ms/step - loss: 1.0599 - accuracy: 0.4775 - val_loss: 1.1213 - val_accuracy: 0.3650
# Epoch 207/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0598 - accuracy: 0.4775 - val_loss: 1.1212 - val_accuracy: 0.3550
# Epoch 208/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0597 - accuracy: 0.4775 - val_loss: 1.1212 - val_accuracy: 0.3550
# Epoch 209/250
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0597 - accuracy: 0.4787 - val_loss: 1.1211 - val_accuracy: 0.3550
# Epoch 210/250
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0596 - accuracy: 0.4762 - val_loss: 1.1210 - val_accuracy: 0.3600
# Epoch 211/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0595 - accuracy: 0.4775 - val_loss: 1.1210 - val_accuracy: 0.3600
# Epoch 212/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0594 - accuracy: 0.4787 - val_loss: 1.1209 - val_accuracy: 0.3600
# Epoch 213/250
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0594 - accuracy: 0.4787 - val_loss: 1.1208 - val_accuracy: 0.3650
# Epoch 214/250
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0593 - accuracy: 0.4775 - val_loss: 1.1207 - val_accuracy: 0.3700
# Epoch 215/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0592 - accuracy: 0.4775 - val_loss: 1.1206 - val_accuracy: 0.3650
# Epoch 216/250
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0591 - accuracy: 0.4787 - val_loss: 1.1206 - val_accuracy: 0.3650
# Epoch 217/250
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0590 - accuracy: 0.4787 - val_loss: 1.1206 - val_accuracy: 0.3650
# Epoch 218/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0589 - accuracy: 0.4812 - val_loss: 1.1207 - val_accuracy: 0.3650
# Epoch 219/250
# 2/2 [==============================] - 0s 56ms/step - loss: 1.0588 - accuracy: 0.4812 - val_loss: 1.1208 - val_accuracy: 0.3650
# Epoch 220/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0588 - accuracy: 0.4825 - val_loss: 1.1208 - val_accuracy: 0.3550
# Epoch 221/250
# 2/2 [==============================] - 0s 79ms/step - loss: 1.0587 - accuracy: 0.4787 - val_loss: 1.1210 - val_accuracy: 0.3550
# Epoch 222/250
# 2/2 [==============================] - 0s 66ms/step - loss: 1.0586 - accuracy: 0.4762 - val_loss: 1.1211 - val_accuracy: 0.3650
# Epoch 223/250
# 2/2 [==============================] - 0s 82ms/step - loss: 1.0585 - accuracy: 0.4775 - val_loss: 1.1213 - val_accuracy: 0.3700
# Epoch 224/250
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0585 - accuracy: 0.4750 - val_loss: 1.1214 - val_accuracy: 0.3700
# Epoch 225/250
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0584 - accuracy: 0.4750 - val_loss: 1.1215 - val_accuracy: 0.3650
# Epoch 226/250
# 2/2 [==============================] - 0s 52ms/step - loss: 1.0583 - accuracy: 0.4737 - val_loss: 1.1216 - val_accuracy: 0.3600
# Epoch 227/250
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0582 - accuracy: 0.4750 - val_loss: 1.1218 - val_accuracy: 0.3600
# Epoch 228/250
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0581 - accuracy: 0.4750 - val_loss: 1.1218 - val_accuracy: 0.3600
# Epoch 229/250
# 2/2 [==============================] - 0s 48ms/step - loss: 1.0580 - accuracy: 0.4750 - val_loss: 1.1219 - val_accuracy: 0.3600
# Epoch 230/250
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0579 - accuracy: 0.4737 - val_loss: 1.1220 - val_accuracy: 0.3600
# Epoch 231/250
# 2/2 [==============================] - 0s 65ms/step - loss: 1.0579 - accuracy: 0.4725 - val_loss: 1.1220 - val_accuracy: 0.3600
# Epoch 232/250
# 2/2 [==============================] - 0s 76ms/step - loss: 1.0578 - accuracy: 0.4725 - val_loss: 1.1220 - val_accuracy: 0.3600
# Epoch 233/250
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0577 - accuracy: 0.4725 - val_loss: 1.1219 - val_accuracy: 0.3600
# Epoch 234/250
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0577 - accuracy: 0.4712 - val_loss: 1.1219 - val_accuracy: 0.3550
# Epoch 235/250
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0575 - accuracy: 0.4712 - val_loss: 1.1219 - val_accuracy: 0.3600
# Epoch 236/250
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0574 - accuracy: 0.4700 - val_loss: 1.1218 - val_accuracy: 0.3600
# Epoch 237/250
# 2/2 [==============================] - 0s 48ms/step - loss: 1.0573 - accuracy: 0.4688 - val_loss: 1.1217 - val_accuracy: 0.3700
# Epoch 238/250
# 2/2 [==============================] - 0s 52ms/step - loss: 1.0573 - accuracy: 0.4712 - val_loss: 1.1217 - val_accuracy: 0.3650
# Epoch 239/250
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0572 - accuracy: 0.4712 - val_loss: 1.1217 - val_accuracy: 0.3700
# Epoch 240/250
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0571 - accuracy: 0.4700 - val_loss: 1.1217 - val_accuracy: 0.3700
# Epoch 241/250
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0571 - accuracy: 0.4712 - val_loss: 1.1218 - val_accuracy: 0.3700
# Epoch 242/250
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0570 - accuracy: 0.4712 - val_loss: 1.1218 - val_accuracy: 0.3700
# Epoch 243/250
# 2/2 [==============================] - 0s 77ms/step - loss: 1.0569 - accuracy: 0.4725 - val_loss: 1.1219 - val_accuracy: 0.3700
# Epoch 244/250
# 2/2 [==============================] - 0s 72ms/step - loss: 1.0568 - accuracy: 0.4762 - val_loss: 1.1220 - val_accuracy: 0.3750
# Epoch 245/250
# 2/2 [==============================] - 0s 67ms/step - loss: 1.0567 - accuracy: 0.4737 - val_loss: 1.1221 - val_accuracy: 0.3750
# Epoch 246/250
# 2/2 [==============================] - 0s 73ms/step - loss: 1.0566 - accuracy: 0.4750 - val_loss: 1.1221 - val_accuracy: 0.3750
# Epoch 247/250
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0565 - accuracy: 0.4725 - val_loss: 1.1222 - val_accuracy: 0.3750
# Epoch 248/250
# 2/2 [==============================] - 0s 69ms/step - loss: 1.0564 - accuracy: 0.4712 - val_loss: 1.1222 - val_accuracy: 0.3800
# Epoch 249/250
# 2/2 [==============================] - 0s 70ms/step - loss: 1.0563 - accuracy: 0.4712 - val_loss: 1.1222 - val_accuracy: 0.3750
# Epoch 250/250
# 2/2 [==============================] - 0s 53ms/step - loss: 1.0563 - accuracy: 0.4725 - val_loss: 1.1222 - val_accuracy: 0.3600

# %%
#plotting loss and accuracy curves

fig, ax = plt.subplots(nrows = 1, ncols = 2, sharey = True)
ax[0].plot(fit.history['loss'],label='Training Loss')
ax[0].plot(fit.history['val_loss'],label='Validation Loss')
ax[1].plot(fit.history['accuracy'],label='Training Accuracy')
ax[1].plot(fit.history['val_accuracy'],label='Validation Accuracy')
ax[0].legend()
ax[1].legend()
plt.show()

# %%
w=model.layers[0].get_weights()[0]
print(w.shape) # 2 filters, for 1 channel, of a 20x1 kernel

fig,axs = plt.subplots(2,1,figsize=[12,6])
fig.suptitle('Model Layer #1 after Training')
for i in range(w.shape[-1]): # for every filter
    axs[0].plot(w[:,0,0,i],marker='d',label=f'Filter n#{i}')
axs[0].legend()
axs[0].set_title('Weights, Time Series #1')
axs[0].set_xlabel('Window Index')

for i in range(w.shape[-1]): # for every filter
    axs[1].plot(w[:,1,0,i],marker='d',label=f'Filter n#{i}')
axs[1].legend()
axs[1].set_title('Weights, Time Series #2')
axs[1].set_xlabel('Window Index')


fig.tight_layout()
# Out:
# (15, 2, 1, 2)

# %% [markdown]
# ## Regularization grid search
#
#
# The initial weights somehow resemble half-sine bump pattern we introduced; the opposite sign due to differently labeled "bumps" is probably accounted for in the hidden layer. Let's test this model with different regularization parameters:

# %%
lambdas = [10**(-i) for i in range(4)]
histories = {}
best_la = lambdas[0]

for la in lambdas:

    print("---- FITTING WITH LAMBDA = {} ----".format(la))


    model_cp = clone_model(model)
    reg = regularizers.L2(la)
    model_cp.layers[0].kernel_regularizer = reg
    model_cp.compile(loss = categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

    fit_cp=model_cp.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_val,y_val),\
                        verbose=0,shuffle=True) 
    histories[str(la)] = fit_cp.history
    if histories[str(la)]['loss'][-1] < histories[str(best_la)]['loss'][-1]: 
        best_la = la

print(best_la)
# Out:
# ---- FITTING WITH LAMBDA = 1 ----
# ---- FITTING WITH LAMBDA = 0.1 ----
# ---- FITTING WITH LAMBDA = 0.01 ----
# ---- FITTING WITH LAMBDA = 0.001 ----
# 0.1

# %%
for key in histories:
    plt.plot(histories[key]['loss'],label=key)
    print(histories[key]['loss'][-1])

plt.legend()
# Out:
# 0.11047638952732086
# 0.0742502436041832
# 0.08821365237236023
# 0.0922478511929512

# %% [markdown]
# # Increasing signal strenght in data generation
