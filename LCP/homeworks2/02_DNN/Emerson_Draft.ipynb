# %% [markdown]
# NEURAL NETWORK PERFOMANCE INVESTIGATION

# %%
#importing stuff needed, including tensorflow
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.layers import Dense

# %%
#First of all let`s generate the data we`ll work with
# number of data
N=4000
# size of each sample
L=2
# box size
B=100

#generating a folder to keep our data
# !mkdir DATA
# Out:
# mkdir: DATA: File exists

# %%
# a nonlinear classifier function of a 2d array x
def f(x,c=1):
    r=0
    if c==1:
        if x[0]>-20 and x[1]>-40 and x[0]+x[1] < 40:
            r=1
    if c==2:
        if (np.sign(x.sum())*np.sign(x[0]))*np.cos(np.linalg.norm(x)/(2*np.pi))>0:
            r=1
    return r

#define function to create data
def filename(s,TYPE=1):
    return "./DATA/"+s+"-for-DNN-"+str(TYPE)+".dat"

# %%
TYPE=1

# random seed for reproducibility
np.random.seed(12345)
print(np.random.randint(0,10),np.random.randint(0,10),np.random.randint(0,10))
# Out:
# 2 5 1

# %%
#generating the data for the default dataset
x,y = (np.random.random((N,2))-0.5)*B, np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)

#let`s generate the files to store the first default dataset and its labels
np.savetxt(filename("data",TYPE),x)
np.savetxt(filename("labels",TYPE),y,fmt="%d")



#generating the data for the second (reduced) dataset
N=3000
x,y = (np.random.random((N,2))-0.5)*B, np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)
#let`s generate the file to store the second dataset and its labels
np.savetxt(filename("data(reduced)",TYPE),x)
np.savetxt(filename("labels(reduced)",TYPE),y,fmt="%d")




#generating the data for the third (increased) dataset
N=10000
x,y = (np.random.random((N,2))-0.5)*B, np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)
#let`s generate the file to store the third dataset (increased) and its labels
np.savetxt(filename("data(increased)",TYPE),x)
np.savetxt(filename("labels(increased)",TYPE),y,fmt="%d")




#generating the data for the forth (augmented) dataset
N=4000
x,y = (np.random.random((N,2))-0.5)*B+np.random.random((N,2)), np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)

#let`s generate the file to store the forth dataset (augmented) and its labels
np.savetxt(filename("data(augmented)",TYPE),x)
np.savetxt(filename("labels(augmented)",TYPE),y,fmt="%d")

# %%
#Now let's load the first dataset to start its analysis
TYPE=1
x = np.loadtxt(filename("data",TYPE),delimiter=' ')
y = np.loadtxt(filename("labels",TYPE),delimiter=' ')
N=len(x)

#plot the labeled data
plt.figure(figsize = (8,8))
plt.scatter(x[:,0],x[:,1],c=y)
plt.show

L = len(x[0])
print(L)

for i in range(10):
    print(x[i],y[i])
# Out:
# 2
# [-31.60811883 -29.54397214] 0.0
# [6.77250291 9.5544703 ] 1.0
# [46.45145197 15.31770969] 0.0
# [24.89066375 15.35698709] 0.0
# [24.77148093 46.13067361] 0.0
# [-49.16117021 -39.35556233] 0.0
# [-20.12962862  15.64111831] 0.0
# [30.98125525 37.21759137] 0.0
# [46.46475974 22.36853469] 0.0
# [14.24753279 21.74536208] 1.0

# %%
#Now let's built two options for neural networks (two different kinds of architectures)

#reproducibility
np.random.seed(204048)

#Let's set a function to divide data from a specific file in training and test set
def split_data(filename_for_data, filename_for_label, k=0.8):
    x = np.loadtxt(filename(filename_for_data,TYPE),delimiter=' ')
    y = np.loadtxt(filename(filename_for_label,TYPE),delimiter=' ')
    N=len(x)
    k=0.8
    N_train = int(k*N)
    # train validation split
    (x_train,y_train) = (x[:N_train],y[:N_train])
    (x_valid,y_valid) = (x[N_train:],y[N_train:])
    # rescaling
    def Rescale(x):
        return (x-x.mean())/np.sqrt(x.var())

    x_train = Rescale(x_train)
    x_valid = Rescale(x_valid)
    return x, y, x_train, x_valid, y_train, y_valid

dX = 2
X1 = np.arange(-50,50+dX, dX)
LG = len(X1)
grid = np.zeros((LG*LG,2))
k=0
for i in range(LG):
    for j in range(LG):
        grid[k,:]=(X1[j],X1[i])
        k=k+1
        # RESCALE
        grid_r = grid/50


def train_and_plot(filename_for_data, filename_for_labels, k=0.8, epoch=400):
    x,y, x_train, x_valid, y_train, y_valid = split_data(filename_for_data,filename_for_labels)
    nepoch=epoch
    for CASE in range(1,3):
        print(CASE)
        if CASE==1:
            model1 = Sequential()
            model1.add(Dense(L,input_shape=(L,),activation='relu')) #input layer
            model1.add(Dense(20,activation='relu')) #first layer
            model1.add(Dense(20,activation='relu')) #second layer
            model1.add(Dense(1,activation='sigmoid')) # final output    
            
            model1.compile(loss='binary_crossentropy',
                            optimizer='adam',
                            metrics=['accuracy'])
            history1=model1.fit(x_train,y_train, epochs=nepoch,batch_size = 50,
                validation_data=(x_valid,y_valid),verbose=0)
            y_pred1 = model1.predict(grid_r)
            f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,6))
            ax1.scatter(grid[:,1], grid[:,0],c=y_pred1)
            ax1.title.set_text('CASE 1') 

            
        if CASE==2:
            model2 = Sequential()
            model2.add(Dense(L,input_shape=(L,),activation='sigmoid')) #input layer
            model2.add(Dense(3,activation='sigmoid'))
            model2.add(Dense(1,activation='sigmoid'))

            model2.compile(loss='binary_crossentropy',
                            optimizer='adam',
                            metrics=['accuracy'])
            history2=model2.fit(x_train,y_train, epochs=nepoch,batch_size = 50,
                validation_data=(x_valid,y_valid),verbose=0)
            y_pred2 = model2.predict(grid_r)

            ax2.scatter(grid[:,0],grid[:,1],c=y_pred2)
            ax2.title.set_text('CASE 2')
    return model1, model2, history1, history2, x_valid, y_valid

# %%
def analysis(model, history, X_test, Y_test, title):
    score = model.evaluate(X_test, Y_test, verbose=0)

    # print performance
    print()
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

    # look into training history

    # summarize history for accuracy
    
    fig, (ax_1, ax_2) = plt.subplots(1, 2, figsize=(14,6))
    fig.title(title)
    ax_1.plot(history.history['accuracy'])
    ax_1.plot(history.history['val_accuracy'])
    ax_1.set(ylabel='model accuracy', xlabel='epoch')
    ax_1.legend(['train', 'test'], loc='best')

    # summarize history for loss
    ax_2.plot(history.history['loss'])
    ax_2.plot(history.history['val_loss'])
    ax_2.set(ylabel='model loss', xlabel='epoch')
    plt.legend(['train', 'test'], loc='best')

    return

# %%
model1, model2, history1, history2, X_test, Y_test = train_and_plot("data", "labels", k=0.8)
# Out:
# 1
# Metal device set to: Apple M1
# 2022-03-18 16:41:59.978092: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-18 16:41:59.978425: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-03-18 16:42:00.172438: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-03-18 16:42:00.348430: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-18 16:42:00.740417: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-18 16:43:29.478555: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2
# 2022-03-18 16:43:29.816874: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-18 16:43:30.369255: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
title1="Model accuracy and loss for Case 1"
title2="Model accuracy and loss for Case 2"
analysis(model1, history1, X_test, Y_test, title1)
analysis(model2, history2, X_test, Y_test, title2)
# Out:
# Test loss: 0.14881868660449982
# Test accuracy: 0.925000011920929
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4741/1749453724.py in <module>
#       1 title1="Model accuracy and loss for Case 1"
#       2 title2="Model accuracy and loss for Case 2"
# ----> 3 analysis(model1, history1, X_test, Y_test, title1)
#       4 analysis(model2, history2, X_test, Y_test, title2)
#
# /tmp/ipykernel_4741/418817478.py in analysis(model, history, X_test, Y_test, title)
#      12
#      13     fig, (ax_1, ax_2) = plt.subplots(1, 2, figsize=(14,6))
# ---> 14     fig.title(title)
#      15     ax_1.plot(history.history['accuracy'])
#      16     ax_1.plot(history.history['val_accuracy'])
#
# AttributeError: 'Figure' object has no attribute 'title'

# %%
model1, model2, history1, history2, X_test, Y_test = train_and_plot("data(reduced)", "labels(reduced)", k=0.8)
title1="Model accuracy and loss for Case 1 and reduced dataset "
title2="Model accuracy and loss for Case 2 and reduced dataset"
analysis(model1, history1, X_test, Y_test, title1)
analysis(model2, history2,  X_test, Y_test, title2)
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4741/2920634136.py in <module>
# ----> 1 model1, model2, history1, history2, X_test, Y_test = train_and_plot("data(reduced)", "labels(reduced)", k=0.8)
#       2 title1="Model accuracy and loss for Case 1 and reduced dataset "
#       3 title2="Model accuracy and loss for Case 2 and reduced dataset"
#       4 analysis(model1, history1, X_test, Y_test, title1)
#       5 analysis(model2, history2,  X_test, Y_test, title2)
#
# /tmp/ipykernel_4741/4103948850.py in train_and_plot(filename_for_data, filename_for_labels, k, epoch)
#      67                             optimizer='adam',
#      68                             metrics=['accuracy'])
# ---> 69             history2=model2.fit(x_train,y_train, epochs=nepoch,batch_size = 50,
#      70                 validation_data=(x_valid,y_valid),verbose=0)
#      71             y_pred2 = model2.predict(grid_r)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1418                 model=self,
#    1419                 steps_per_execution=self._steps_per_execution)
# -> 1420           val_logs = self.evaluate(
#    1421               x=val_x,
#    1422               y=val_y,
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1708       self._test_counter.assign(0)
#    1709       callbacks.on_test_begin()
# -> 1710       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1711         self.reset_metrics()
#    1712         with data_handler.catch_stop_iteration():
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3313   if tld.is_eager:
#    3314     try:
# -> 3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#
# KeyboardInterrupt:

# %%
model1, model2, history1, history2, X_test, Y_test = train_and_plot("data(increased)", "labels(increased)", k=0.8)
title1="Model accuracy and loss for Case 1 and increased dataset "
title2="Model accuracy and loss for Case 2 and increased dataset"
analysis(model1, history1, X_test, Y_test, title1)
analysis(model2, history2,  X_test, Y_test, title2)
# Out:
# 1
# 2
#
# Test loss: 0.041410546749830246
# Test accuracy: 0.984499990940094
#
# Test loss: 0.23447753489017487
# Test accuracy: 0.9204999804496765

# %%
model1, model2, history1, history2, X_test, Y_test = train_and_plot("data(augmented)", "labels(augmented)", k=0.8)
title1="Model accuracy and loss for Case 1 and augmented dataset "
title2="Model accuracy and loss for Case 2 and augmented dataset"
analysis(model1, history1, X_test, Y_test, title1)
analysis(model2, history2,  X_test, Y_test, title2)
# Out:
# 1
# 2
#
# Test loss: 0.055034294724464417
# Test accuracy: 0.9775000214576721
#
# Test loss: 0.24526160955429077
# Test accuracy: 0.9125000238418579
